# %%
# %pip install langdetect
# Out:
# Requirement already satisfied: langdetect in c:\users\029at\appdata\local\programs\python\python310\lib\site-packages (1.0.9)
# Requirement already satisfied: six in c:\users\029at\appdata\local\programs\python\python310\lib\site-packages (from langdetect) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import các thư viện cần thiết

# %%
import os
from tqdm import tqdm
from typing import List
import pandas as pd

from langdetect import detect
from langdetect import DetectorFactory

# Display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Tiền xử lý dữ liệu transcription từ video

# %% [markdown]
# Liệt kê đường dẫn đến các file .csv cần thiết

# %%
def list_file_types(directory: str, file_extension: str) -> List[str]:
    """ List all files with a specific extension in a directory.

    Args:
        directory (str): Directory path.
        file_extension (str): File extension.

    Returns:
        List[str]: List of file paths.
    """

    file_list: List[str] = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(file_extension):
                file_list.append(os.path.join(root, file))
    return file_list


transcription_files = list_file_types("../../data/VideoTranscription", ".csv")
transcription_files[:5]
# Out:
# ['../../data/VideoTranscription\\Kaggle\\0000000000000000_audio_transcription_12800_13000.csv',
#  '../../data/VideoTranscription\\Kaggle\\0000000000000000_audio_transcription_13000_13200.csv',
#  '../../data/VideoTranscription\\Kaggle\\0000000000000000_audio_transcription_13200_13400.csv',
#  '../../data/VideoTranscription\\Kaggle\\0000000000000000_audio_transcription_13400_13600.csv',
#  '../../data/VideoTranscription\\Kaggle\\0000000000000000_audio_transcription_13600_13800.csv']

# %% [markdown]
# Đọc lần lượt các file .csv thành các DataFrame và lưu vào một list. Đồng thời tạo thêm một cột `url` chứa đường dẫn đến TikTok video tương ứng với mỗi transcription.

# %%
# Create a function to format TikTok URLs
def format_tiktok_url(author_id: str, video_id: str) -> str:
    """ Format TikTok URL.

    Args:
        author_id (str): ID of the author.
        video_id (str): ID of the video.

    Returns:
        str: TikTok URL.
    """

    return f"https://www.tiktok.com/@{author_id}/video/{video_id}"

# %%
df_list: List[pd.DataFrame] = []

for transcription_file in tqdm(transcription_files):
    # Load the CSV file
    df = pd.read_csv(transcription_file)

    # Apply the function to create or update the URL column
    df['url'] = df.apply(lambda row: format_tiktok_url(
        row['author_id'], row['video_id']), axis=1)

    # Select columns order
    df[['author_id', 'video_id', 'video_transcription', 'url']]

    # Append the DataFrame to the list
    df_list.append(df)
# Out:
# 100%|██████████| 75/75 [00:01<00:00, 62.41it/s]

# %% [markdown]
# Merge các DataFrame trong list thành một DataFrame duy nhất.

# %%
# Concatenate all DataFrames in the list
transcription_df = pd.concat(df_list, ignore_index=True)
transcription_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33501 entries, 0 to 33500
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            33501 non-null  int64
#  1   video_id             33501 non-null  int64
#  2   video_transcription  28929 non-null  object
#  3   url                  33501 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# **Nhận xét:**
#
# - Ta thấy có nhiều video không có transcription, ta sẽ loại bỏ các dòng này.

# %% [markdown]
# Loại bỏ các dòng bị thiếu dữ liệu.

# %%
# Remove rows with missing values
transcription_df = transcription_df.dropna(
    axis='index', how='any'
)

# Reset index after removing rows
transcription_df = transcription_df.reset_index(drop=True)

transcription_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28929 entries, 0 to 28928
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            28929 non-null  int64
#  1   video_id             28929 non-null  int64
#  2   video_transcription  28929 non-null  object
#  3   url                  28929 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 904.2+ KB

# %% [markdown]
# Loại bỏ các dòng có transcription ít hơn 50 từ (word).

# %%
# Remove rows with less than 50 words in the transcription
transcription_df = transcription_df[
    transcription_df['video_transcription'].str.split().apply(len) >= 50
]

# Reset index after removing rows
transcription_df = transcription_df.reset_index(drop=True)

transcription_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23825 entries, 0 to 23824
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            23825 non-null  int64
#  1   video_id             23825 non-null  int64
#  2   video_transcription  23825 non-null  object
#  3   url                  23825 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 744.7+ KB

# %% [markdown]
# Loại bỏ các dòng có transcription không phải tiếng Việt.

# %%
# Create a new column for the detected language
transcription_df["language"] = ["error"] * len(transcription_df)

# Detect the language of the transcription
for index in tqdm(range(len(transcription_df))):
    try:
        DetectorFactory.seed = 0
        transcription_df.loc[index, "language"] = detect(
            transcription_df.loc[index, "video_transcription"])
    except:
        transcription_df.loc[index, "language"] = "error"
# Out:
# 100%|██████████| 23825/23825 [01:40<00:00, 237.07it/s]

# %% [markdown]
# Số lượng transcription bằng tiếng Việt còn lại sau khi loại bỏ các dòng không hợp lệ.

# %%
sum(transcription_df['language'] == 'vi')
# Out:
# 23765

# %%
# Remove rows with non-Vietnamese transcriptions
transcription_df = transcription_df[
    transcription_df['language'] == 'vi'
]

# Reset index after removing rows
transcription_df = transcription_df.reset_index(drop=True)

transcription_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23765 entries, 0 to 23764
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            23765 non-null  int64
#  1   video_id             23765 non-null  int64
#  2   video_transcription  23765 non-null  object
#  3   url                  23765 non-null  object
#  4   language             23765 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 928.4+ KB

# %%
transcription_df.sample(n=5)
# Out:
#                  author_id             video_id  \
# 20527  7080408427277190145  7464518477731204360
# 6049   6908933207383639041  7420682548054936839
# 3242   6844492227462267905  7368040029412674832
# 18096  7255941113726321666  7415952588656413960
# 19200  6573106305933475841  7470143947986308360
#
#                                      video_transcription  \
# 20527  Bây giờ là 2 giờ chiều nhưng mà tiến hành vào ...
# 6049   đi từ 4 giờ đúng không có nhà ai như nhà mình ...
# 3242   136 món hải sản như thế này chưa tới một củ mọ...
# 18096  Xin chào mọi người Hôm nay ăn một mẹ đồ ăn tha...
# 19200  Hồi chiều tới giờ mà còn đọc được cái vụ này c...
#
#                                                      url language
# 20527  https://www.tiktok.com/@7080408427277190145/vi...       vi
# 6049   https://www.tiktok.com/@6908933207383639041/vi...       vi
# 3242   https://www.tiktok.com/@6844492227462267905/vi...       vi
# 18096  https://www.tiktok.com/@7255941113726321666/vi...       vi
# 19200  https://www.tiktok.com/@6573106305933475841/vi...       vi

# %% [markdown]
# Chuyển kiểu dữ liệu của tất cả các cột thành kiểu `str`

# %%
# Convert data type of all columns to string
transcription_df = transcription_df.astype(str)
transcription_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23765 entries, 0 to 23764
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            23765 non-null  object
#  1   video_id             23765 non-null  object
#  2   video_transcription  23765 non-null  object
#  3   url                  23765 non-null  object
#  4   language             23765 non-null  object
# dtypes: object(5)
# memory usage: 928.4+ KB

# %% [markdown]
# Loại bỏ các dòng bị trùng lặp. Dựa trên cột `video_id` để xác định dòng nào là trùng lặp. Với các dòng trùng lặp, ta chỉ giữ lại dòng đầu tiên.

# %%
# Display number of rows before deduplication
print(f"Before: {len(transcription_df)}")

# Remove duplicates based on video_id column, keeping the first occurrence
transcription_df = transcription_df.drop_duplicates(
    subset=["video_id"], keep='first'
)

# Reset index after deduplication
transcription_df = transcription_df.reset_index(drop=True)

# Display number of rows after deduplication
print(f"After: {len(transcription_df)}")
# Out:
# Before: 23765
# After: 23099

# %% [markdown]
# # 2. Tiền xử lý dữ liệu thống kê từ video

# %% [markdown]
# Đọc dữ liệu thống kê video thành DataFrame.

# %%
video_info_df = pd.read_csv("../../data/interim/video_info.csv", low_memory=False)
video_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32603 entries, 0 to 32602
# Columns: 136 entries, AIGCDescription to audio_to_text
# dtypes: bool(20), float64(37), int64(36), object(43)
# memory usage: 29.5+ MB

# %% [markdown]
# Loại bỏ các cột có tỷ lệ thiếu dữ liệu lớn hơn 50%

# %%
# Calculate the missing ratio
missing_ratio = video_info_df.isna().sum() / len(video_info_df)

# Sort the missing ratio in descending order
missing_ratio = missing_ratio.sort_values(ascending=False)

# Display first 5 rows
missing_ratio.head()
# Out:
# AIGCDescription               1.0
# backendSourceEventTracking    1.0
# music.coverThumb              1.0
# music.coverMedium             1.0
# music.coverLarge              1.0
# dtype: float64

# %%
# Remove columns with missing ratios greater than 0.50
video_info_df = video_info_df.dropna(
    axis='columns', thresh=0.50 * len(video_info_df)
)

# %%
# Calculate the missing ratio
missing_ratio = video_info_df.isna().sum() / len(video_info_df)

# Sort the missing ratio in descending order
missing_ratio = missing_ratio.sort_values(ascending=False)

# Display the missing ratio
for column, ratio in missing_ratio[:5].items():
    print(f"{column:50}:{ratio:8.2%}")
# Out:
# duetEnabled                                       :  20.29%
# stitchEnabled                                     :  19.87%
# video.claInfo.originalLanguageInfo.languageID     :  18.91%
# video.claInfo.originalLanguageInfo.languageCode   :  18.91%
# video.claInfo.originalLanguageInfo.language       :  18.91%

# %%
# video_info_df.info()

# %% [markdown]
# Vì các cột có tên bắt đầu với `stats.*` chứa cùng thông tin với các cột có tên bắt đầu với `statsV2.*`, nhưng không có thông tin về `repostCount` như `statsV2.*`. Nên ta sẽ loại bỏ các cột có tên bắt đầu với `stats.*`.

# %%
# Remove columns starting with "stats."
video_info_df = video_info_df[
    [column for column in video_info_df.columns
            if not column.startswith("stats.")]
]

# video_info_df.info()

# %% [markdown]
# Xóa các cột bắt đầu với `video.claInfo.originalLanguageInfo.*` vì chúng chứa thông tin không cần thiết.

# %%
# Remove columns starting with "video.claInfo.originalLanguageInfo."
video_info_df = video_info_df[
    [column for column in video_info_df.columns
            if not column.startswith("video.claInfo.originalLanguageInfo.")]
]

# video_info_df.info()

# %% [markdown]
# Tạo một cột chứa danh sách các `hashtag` được trích xuất từ mô tả video. Và tính số lượng hashtag trong mỗi video.

# %%
# Replace missing values in "desc" column with an empty string
video_info_df["desc"] = video_info_df["desc"].fillna("")
video_info_df["desc"] = video_info_df["desc"].astype(str)
video_info_df["desc"] = video_info_df["desc"].str.strip()

# Create a new column for the hashtags
# and the number of hashtags in each video
video_info_df["hashtags"] = [""] * len(video_info_df)
video_info_df["num_hashtags"] = [0] * len(video_info_df)

# Extract hashtags from the "desc" column
# and Get the number of hashtags in each video
for index in tqdm(range(len(video_info_df))):
    # Get the description of the video
    description = video_info_df.loc[index, "desc"].strip().lower()

    if description:
        # Remove emojis
        description = description.encode('ascii', 'ignore').decode('ascii')

        # Add a space before all "#" characters
        description = description.replace("#", " #")

        # Find all strings starting with "#" and followed by a word
        hashtags = [word[1:] for word in description.split()
                    if word.startswith("#")]

        # Extract hashtags from the description
        video_info_df.loc[index, "hashtags"] = ",".join(hashtags).strip()

        # Get the number of hashtags
        video_info_df.loc[index, "num_hashtags"] = len(hashtags)
    else:
        video_info_df.loc[index, "hashtags"] = ""
        video_info_df.loc[index, "num_hashtags"] = 0
# Out:
# 100%|██████████| 32603/32603 [00:06<00:00, 4718.58it/s]

# %%
video_info_df[["hashtags", "num_hashtags"]].sample(n=5)
# Out:
#                                                 hashtags  num_hashtags
# 10953  saigon,didausaigon,binhthanh,ancungtiktok,lear...             5
# 843    anchoivungtau,anchoivungtau72,xuhuong,fyp,duli...            10
# 16288  learnontiktok,ancungtiktok,xuhuong,tiktokfood,...             6
# 27993  tieumanthau,learnontiktok,vtmgr,ancungtiktok,c...            13
# 13197  onganhthichnauan,fyp,cooking,vanmonngonbungvi,...             5

# %%
video_info_df['hashtags'] = video_info_df['hashtags'].apply(lambda x: x.split(',') if isinstance(x, str) and x.strip() else [])
video_info_df["hashtags"] = video_info_df["hashtags"].apply(lambda x: x if isinstance(x, list) else [])

# %%
video_info_df['createTime'] = pd.to_datetime(video_info_df['createTime'], unit='s')

# %% [markdown]
# # 3. Nối dữ liệu transcription và dữ liệu thống kê

# %% [markdown]
# Merge hai DataFrame transcription và DataFrame thống kê thành một DataFrame duy nhất. Sử dụng videoId làm khóa ngoại.

# %%
# Convert data type of video.id to string
video_info_df["video.id"] = video_info_df["video.id"].astype(str)
transcription_df["video_id"] = transcription_df["video_id"].astype(str)

# Merge the DataFrames
merged_df = pd.merge(
    left=video_info_df,
    right=transcription_df,
    how="inner",
    left_on="video.id",
    right_on="video_id"
)

# Reset index after merging
merged_df = merged_df.reset_index(drop=True)

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23099 entries, 0 to 23098
# Data columns (total 84 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CategoryType                     23099 non-null  int64
#  1   author.commentSetting            23099 non-null  int64
#  2   author.downloadSetting           23099 non-null  int64
#  3   author.duetSetting               23099 non-null  int64
#  4   author.ftc                       23099 non-null  bool
#  5   author.id                        23099 non-null  int64
#  6   author.isADVirtual               23099 non-null  bool
#  7   author.isEmbedBanned             23099 non-null  bool
#  8   author.nickname                  23099 non-null  object
#  9   author.openFavorite              23099 non-null  bool
#  10  author.privateAccount            23099 non-null  bool
#  11  author.relation                  23099 non-null  int64
#  12  author.secUid                    23099 non-null  object
#  13  author.secret                    23099 non-null  bool
#  14  author.signature                 23086 non-null  object
#  15  author.stitchSetting             23099 non-null  int64
#  16  author.uniqueId                  23099 non-null  object
#  17  author.verified                  23099 non-null  bool
#  18  authorStats.diggCount            23099 non-null  int64
#  19  authorStats.followerCount        23099 non-null  int64
#  20  authorStats.followingCount       23099 non-null  int64
#  21  authorStats.friendCount          23099 non-null  int64
#  22  authorStats.heart                23099 non-null  int64
#  23  authorStats.heartCount           23099 non-null  int64
#  24  authorStats.videoCount           23099 non-null  int64
#  25  collected                        23099 non-null  bool
#  26  createTime                       23099 non-null  datetime64[ns]
#  27  desc                             23099 non-null  object
#  28  digged                           23099 non-null  bool
#  29  diversificationId                21998 non-null  float64
#  30  duetDisplay                      23099 non-null  int64
#  31  duetEnabled                      18675 non-null  object
#  32  forFriend                        23099 non-null  bool
#  33  id                               23099 non-null  int64
#  34  isAd                             23099 non-null  bool
#  35  itemCommentStatus                23099 non-null  int64
#  36  item_control.can_repost          23099 non-null  bool
#  37  music.authorName                 23072 non-null  object
#  38  music.duration                   23072 non-null  float64
#  39  music.id                         23099 non-null  int64
#  40  music.isCopyrighted              23099 non-null  bool
#  41  music.original                   23099 non-null  bool
#  42  music.title                      23077 non-null  object
#  43  officalItem                      23099 non-null  bool
#  44  originalItem                     23099 non-null  bool
#  45  privateItem                      23099 non-null  bool
#  46  secret                           23099 non-null  bool
#  47  shareEnabled                     23099 non-null  bool
#  48  statsV2.collectCount             23099 non-null  int64
#  49  statsV2.commentCount             23099 non-null  int64
#  50  statsV2.diggCount                23099 non-null  int64
#  51  statsV2.playCount                23099 non-null  int64
#  52  statsV2.repostCount              23099 non-null  int64
#  53  statsV2.shareCount               23099 non-null  int64
#  54  stitchDisplay                    23099 non-null  int64
#  55  stitchEnabled                    18713 non-null  object
#  56  textLanguage                     23099 non-null  object
#  57  textTranslatable                 23099 non-null  bool
#  58  video.VQScore                    22915 non-null  float64
#  59  video.bitrate                    22915 non-null  float64
#  60  video.claInfo.enableAutoCaption  22914 non-null  object
#  61  video.claInfo.hasOriginalAudio   22914 non-null  object
#  62  video.codecType                  22915 non-null  object
#  63  video.definition                 22915 non-null  object
#  64  video.duration                   23099 non-null  int64
#  65  video.encodedType                22915 non-null  object
#  66  video.format                     22915 non-null  object
#  67  video.height                     23099 non-null  int64
#  68  video.id                         23099 non-null  object
#  69  video.ratio                      22915 non-null  object
#  70  video.videoID                    22915 non-null  object
#  71  video.videoQuality               22915 non-null  object
#  72  video.volumeInfo.Loudness        22914 non-null  float64
#  73  video.volumeInfo.Peak            22914 non-null  float64
#  74  video.width                      23099 non-null  int64
#  75  collectTime                      23099 non-null  int64
#  76  video.claInfo.captionsType       21803 non-null  float64
#  77  hashtags                         23099 non-null  object
#  78  num_hashtags                     23099 non-null  int64
#  79  author_id                        23099 non-null  object
#  80  video_id                         23099 non-null  object
#  81  video_transcription              23099 non-null  object
#  82  url                              23099 non-null  object
#  83  language                         23099 non-null  object
# dtypes: bool(20), datetime64[ns](1), float64(7), int64(30), object(26)
# memory usage: 11.7+ MB

# %% [markdown]
# Kiểm tra các hàng bị trùng lặp và loại bỏ chúng.

# %%
num_duplicates = merged_df.duplicated(subset=["video_id"]).sum()
num_duplicates
# Out:
# 0

# %% [markdown]
# Loại bỏ các cột có cùng thông tin với các cột khác: `author_id`, `video_id`, v.v.

# %%
# Remove redundant columns
redundant_columns = [
    "video_id", "author_id", "language"
]
merged_df = merged_df.drop(columns=redundant_columns, axis=1,
                           errors='ignore')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23099 entries, 0 to 23098
# Data columns (total 81 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CategoryType                     23099 non-null  int64
#  1   author.commentSetting            23099 non-null  int64
#  2   author.downloadSetting           23099 non-null  int64
#  3   author.duetSetting               23099 non-null  int64
#  4   author.ftc                       23099 non-null  bool
#  5   author.id                        23099 non-null  int64
#  6   author.isADVirtual               23099 non-null  bool
#  7   author.isEmbedBanned             23099 non-null  bool
#  8   author.nickname                  23099 non-null  object
#  9   author.openFavorite              23099 non-null  bool
#  10  author.privateAccount            23099 non-null  bool
#  11  author.relation                  23099 non-null  int64
#  12  author.secUid                    23099 non-null  object
#  13  author.secret                    23099 non-null  bool
#  14  author.signature                 23086 non-null  object
#  15  author.stitchSetting             23099 non-null  int64
#  16  author.uniqueId                  23099 non-null  object
#  17  author.verified                  23099 non-null  bool
#  18  authorStats.diggCount            23099 non-null  int64
#  19  authorStats.followerCount        23099 non-null  int64
#  20  authorStats.followingCount       23099 non-null  int64
#  21  authorStats.friendCount          23099 non-null  int64
#  22  authorStats.heart                23099 non-null  int64
#  23  authorStats.heartCount           23099 non-null  int64
#  24  authorStats.videoCount           23099 non-null  int64
#  25  collected                        23099 non-null  bool
#  26  createTime                       23099 non-null  datetime64[ns]
#  27  desc                             23099 non-null  object
#  28  digged                           23099 non-null  bool
#  29  diversificationId                21998 non-null  float64
#  30  duetDisplay                      23099 non-null  int64
#  31  duetEnabled                      18675 non-null  object
#  32  forFriend                        23099 non-null  bool
#  33  id                               23099 non-null  int64
#  34  isAd                             23099 non-null  bool
#  35  itemCommentStatus                23099 non-null  int64
#  36  item_control.can_repost          23099 non-null  bool
#  37  music.authorName                 23072 non-null  object
#  38  music.duration                   23072 non-null  float64
#  39  music.id                         23099 non-null  int64
#  40  music.isCopyrighted              23099 non-null  bool
#  41  music.original                   23099 non-null  bool
#  42  music.title                      23077 non-null  object
#  43  officalItem                      23099 non-null  bool
#  44  originalItem                     23099 non-null  bool
#  45  privateItem                      23099 non-null  bool
#  46  secret                           23099 non-null  bool
#  47  shareEnabled                     23099 non-null  bool
#  48  statsV2.collectCount             23099 non-null  int64
#  49  statsV2.commentCount             23099 non-null  int64
#  50  statsV2.diggCount                23099 non-null  int64
#  51  statsV2.playCount                23099 non-null  int64
#  52  statsV2.repostCount              23099 non-null  int64
#  53  statsV2.shareCount               23099 non-null  int64
#  54  stitchDisplay                    23099 non-null  int64
#  55  stitchEnabled                    18713 non-null  object
#  56  textLanguage                     23099 non-null  object
#  57  textTranslatable                 23099 non-null  bool
#  58  video.VQScore                    22915 non-null  float64
#  59  video.bitrate                    22915 non-null  float64
#  60  video.claInfo.enableAutoCaption  22914 non-null  object
#  61  video.claInfo.hasOriginalAudio   22914 non-null  object
#  62  video.codecType                  22915 non-null  object
#  63  video.definition                 22915 non-null  object
#  64  video.duration                   23099 non-null  int64
#  65  video.encodedType                22915 non-null  object
#  66  video.format                     22915 non-null  object
#  67  video.height                     23099 non-null  int64
#  68  video.id                         23099 non-null  object
#  69  video.ratio                      22915 non-null  object
#  70  video.videoID                    22915 non-null  object
#  71  video.videoQuality               22915 non-null  object
#  72  video.volumeInfo.Loudness        22914 non-null  float64
#  73  video.volumeInfo.Peak            22914 non-null  float64
#  74  video.width                      23099 non-null  int64
#  75  collectTime                      23099 non-null  int64
#  76  video.claInfo.captionsType       21803 non-null  float64
#  77  hashtags                         23099 non-null  object
#  78  num_hashtags                     23099 non-null  int64
#  79  video_transcription              23099 non-null  object
#  80  url                              23099 non-null  object
# dtypes: bool(20), datetime64[ns](1), float64(7), int64(30), object(23)
# memory usage: 11.2+ MB

# %%
merged_df.sample(n=2)
# Out:
#        CategoryType  author.commentSetting  author.downloadSetting  \
# 19937           111                      0                       3
# 16905           111                      0                       0
#
#        author.duetSetting  author.ftc            author.id  \
# 19937                   0       False  6908933207383639041
# 16905                   0       False  6859343544352687105
#
#        author.isADVirtual  author.isEmbedBanned author.nickname  \
# 19937               False                 False   Tiểu Màn Thầu
# 16905               False                 False    Đỗ Phượng Vỹ
#
#        author.openFavorite  author.privateAccount  author.relation  \
# 19937                False                  False                0
# 16905                False                  False                0
#
#                                            author.secUid  author.secret  \
# 19937  MS4wLjABAAAA3wojSkfJjQnNK5vyHC5eLhP8A-GpvIp5VU...          False
# 16905  MS4wLjABAAAAVSMqrednlizzyF26dxOdZvQSoVWurvluz-...          False
#
#                                         author.signature  \
# 19937  Contact for work: 093 4307361 (Lan Anh)\r\n--\...
# 16905  Đặt sữa hạt ở phở: Đỗ Phượng Vỹ\r\nEmail: Doph...
#
#        author.stitchSetting author.uniqueId  author.verified  \
# 19937                     0   tieumanthaune             True
# 16905                     0   phuongvy_1105            False
#
#        authorStats.diggCount  authorStats.followerCount  \
# 19937                  25100                    3300000
# 16905                   1643                    2100000
#
#        authorStats.followingCount  authorStats.friendCount  authorStats.heart  \
# 19937                         168                        0          111500000
# 16905                         113                        0           57900000
#
#        authorStats.heartCount  authorStats.videoCount  collected  \
# 19937               111500000                    1104      False
# 16905                57900000                    1006      False
#
#                createTime                                               desc  \
# 19937 2024-02-21 15:06:15  💯 Tự nhiên cái trời nóng ghê! #tieumanthau #Le...
# 16905 2024-05-06 07:18:14  Mùa sầu riêng tới rồi mn ơi 🤭 #phuongvy_1105 #...
#
#        digged  diversificationId  duetDisplay duetEnabled  forFriend  \
# 19937   False            10085.0            0        True      False
# 16905   False            10039.0            0        True      False
#
#                         id   isAd  itemCommentStatus  item_control.can_repost  \
# 19937  7338071754339994887  False                  0                     True
# 16905  7365782525785951495  False                  0                     True
#
#       music.authorName  music.duration             music.id  \
# 19937             dama           486.0  6925885701440178178
# 16905     Đỗ Phượng Vỹ           145.0  7365782682250644225
#
#        music.isCopyrighted  music.original  \
# 19937                False           False
# 16905                False           False
#
#                                   music.title  officalItem  originalItem  \
# 19937  Cute background music for kids(951274)        False         False
# 16905                    nhạc nền - Phượng Vỹ        False         False
#
#        privateItem  secret  shareEnabled  statsV2.collectCount  \
# 19937        False   False          True                   430
# 16905        False   False          True                  1237
#
#        statsV2.commentCount  statsV2.diggCount  statsV2.playCount  \
# 19937                    57              18200             345600
# 16905                   749              60700            1500000
#
#        statsV2.repostCount  statsV2.shareCount  stitchDisplay stitchEnabled  \
# 19937                    0                  71              0          True
# 16905                    0                2186              0          True
#
#       textLanguage  textTranslatable  video.VQScore  video.bitrate  \
# 19937           vi              True          69.27      1502891.0
# 16905           vi              True            NaN            NaN
#
#       video.claInfo.enableAutoCaption video.claInfo.hasOriginalAudio  \
# 19937                            True                           True
# 16905                             NaN                            NaN
#
#       video.codecType video.definition  video.duration video.encodedType  \
# 19937            h264             540p              59            normal
# 16905             NaN              NaN               0               NaN
#
#       video.format  video.height             video.id video.ratio  \
# 19937          mp4          1024  7338071754339994887        540p
# 16905          NaN             0  7365782525785951495         NaN
#
#                           video.videoID video.videoQuality  \
# 19937  v10044g50000cnb123vog65q0fhqtvh0             normal
# 16905                               NaN                NaN
#
#        video.volumeInfo.Loudness  video.volumeInfo.Peak  video.width  \
# 19937                      -15.0                0.60256          576
# 16905                        NaN                    NaN            0
#
#        collectTime  video.claInfo.captionsType  \
# 19937   1741176068                         1.0
# 16905   1741177527                         NaN
#
#                                                 hashtags  num_hashtags  \
# 19937  [tieumanthau, learnontiktok, vtmgr, ancungtikt...            10
# 16905  [phuongvy_1105, ancungtiktok, anngonnaugon, tr...             4
#
#                                      video_transcription  \
# 19937  cách làm mùa hè tới rồi hay sao nóng quá nha m...
# 16905  Tổng cộng là có bốn cái trong đó thì có 3 trái...
#
#                                                      url
# 19937  https://www.tiktok.com/@6908933207383639041/vi...
# 16905  https://www.tiktok.com/@6859343544352687105/vi...

# %%
merged_df
# Out:
#        CategoryType  author.commentSetting  author.downloadSetting  \
# 0               111                      0                       0
# 1               105                      0                       0
# 2               111                      0                       0
# 3               111                      0                       0
# 4               105                      0                       0
# ...             ...                    ...                     ...
# 23094             0                      0                       3
# 23095           105                      0                       3
# 23096           111                      0                       3
# 23097           111                      0                       3
# 23098           111                      0                       3
#
#        author.duetSetting  author.ftc            author.id  \
# 0                       0       False  7128234498731803674
# 1                       0       False  7128234498731803674
# 2                       0       False  7128234498731803674
# 3                       0       False  7128234498731803674
# 4                       0       False  7128234498731803674
# ...                   ...         ...                  ...
# 23094                   0       False  6644110999556227073
# 23095                   0       False  6644110999556227073
# 23096                   0       False  6644110999556227073
# 23097                   0       False  6644110999556227073
# 23098                   0       False  6644110999556227073
#
#        author.isADVirtual  author.isEmbedBanned author.nickname  \
# 0                   False                 False  1 phút Sài Gòn
# 1                   False                 False  1 phút Sài Gòn
# 2                   False                 False  1 phút Sài Gòn
# 3                   False                 False  1 phút Sài Gòn
# 4                   False                 False  1 phút Sài Gòn
# ...                   ...                   ...             ...
# 23094               False                 False    Quynh Truong
# 23095               False                 False    Quynh Truong
# 23096               False                 False    Quynh Truong
# 23097               False                 False    Quynh Truong
# 23098               False                 False    Quynh Truong
#
#        author.openFavorite  author.privateAccount  author.relation  \
# 0                    False                  False                0
# 1                    False                  False                0
# 2                    False                  False                0
# 3                    False                  False                0
# 4                    False                  False                0
# ...                    ...                    ...              ...
# 23094                False                  False                0
# 23095                False                  False                0
# 23096                False                  False                0
# 23097                False                  False                0
# 23098                False                  False                0
#
#                                            author.secUid  author.secret  \
# 0      MS4wLjABAAAA3QoEqn5xhIihiigzt7wJcPLXYYrGZb60yQ...          False
# 1      MS4wLjABAAAA3QoEqn5xhIihiigzt7wJcPLXYYrGZb60yQ...          False
# 2      MS4wLjABAAAA3QoEqn5xhIihiigzt7wJcPLXYYrGZb60yQ...          False
# 3      MS4wLjABAAAA3QoEqn5xhIihiigzt7wJcPLXYYrGZb60yQ...          False
# 4      MS4wLjABAAAA3QoEqn5xhIihiigzt7wJcPLXYYrGZb60yQ...          False
# ...                                                  ...            ...
# 23094  MS4wLjABAAAA6e26Ok_w7ReVcKXUIZoygasHXTl9ZPPvhm...          False
# 23095  MS4wLjABAAAA6e26Ok_w7ReVcKXUIZoygasHXTl9ZPPvhm...          False
# 23096  MS4wLjABAAAA6e26Ok_w7ReVcKXUIZoygasHXTl9ZPPvhm...          False
# 23097  MS4wLjABAAAA6e26Ok_w7ReVcKXUIZoygasHXTl9ZPPvhm...          False
# 23098  MS4wLjABAAAA6e26Ok_w7ReVcKXUIZoygasHXTl9ZPPvhm...          False
#
#                                         author.signature  \
# 0        Lụm lặt những điều nhỏ nhỏ dễ thương ở Sài Gòn.
# 1        Lụm lặt những điều nhỏ nhỏ dễ thương ở Sài Gòn.
# 2        Lụm lặt những điều nhỏ nhỏ dễ thương ở Sài Gòn.
# 3        Lụm lặt những điều nhỏ nhỏ dễ thương ở Sài Gòn.
# 4        Lụm lặt những điều nhỏ nhỏ dễ thương ở Sài Gòn.
# ...                                                  ...
# 23094  Thấy mình đáng iu thì fl mình nhé hehee\r\n💬Fo...
# 23095  Thấy mình đáng iu thì fl mình nhé hehee\r\n💬Fo...
# 23096  Thấy mình đáng iu thì fl mình nhé hehee\r\n💬Fo...
# 23097  Thấy mình đáng iu thì fl mình nhé hehee\r\n💬Fo...
# 23098  Thấy mình đáng iu thì fl mình nhé hehee\r\n💬Fo...
#
#        author.stitchSetting author.uniqueId  author.verified  \
# 0                         0     1phutsaigon            False
# 1                         0     1phutsaigon            False
# 2                         0     1phutsaigon            False
# 3                         0     1phutsaigon            False
# 4                         0     1phutsaigon            False
# ...                     ...             ...              ...
# 23094                     0        _ttqueen            False
# 23095                     0        _ttqueen            False
# 23096                     0        _ttqueen            False
# 23097                     0        _ttqueen            False
# 23098                     0        _ttqueen            False
#
#        authorStats.diggCount  authorStats.followerCount  \
# 0                       2128                     198700
# 1                       2128                     198700
# 2                       2128                     198700
# 3                       2128                     198700
# 4                       2128                     198700
# ...                      ...                        ...
# 23094                   4634                    2900000
# 23095                   4634                    2900000
# 23096                   4634                    2900000
# 23097                   4634                    2900000
# 23098                   4634                    2900000
#
#        authorStats.followingCount  authorStats.friendCount  authorStats.heart  \
# 0                              47                        0            4100000
# 1                              47                        0            4100000
# 2                              47                        0            4100000
# 3                              47                        0            4100000
# 4                              47                        0            4100000
# ...                           ...                      ...                ...
# 23094                          98                        0           83700000
# 23095                          98                        0           83700000
# 23096                          98                        0           83700000
# 23097                          98                        0           83700000
# 23098                          98                        0           83700000
#
#        authorStats.heartCount  authorStats.videoCount  collected  \
# 0                     4100000                     847      False
# 1                     4100000                     847      False
# 2                     4100000                     847      False
# 3                     4100000                     847      False
# 4                     4100000                     847      False
# ...                       ...                     ...        ...
# 23094                83700000                     373      False
# 23095                83700000                     373      False
# 23096                83700000                     373      False
# 23097                83700000                     373      False
# 23098                83700000                     374      False
#
#                createTime                                               desc  \
# 0     2025-02-13 14:08:47  Phát hiện chiếc quán có nóc nhà cực chill, nơi...
# 1     2025-01-28 12:08:58  Tổng hợp các địa điểm du Xuân chụp hình Tết ở ...
# 2     2025-01-19 14:15:33  Phát hiện khu vườn ngập tràn sắc xuân xinh xắn...
# 3     2025-01-15 13:00:20  Phát hiện con hẻm chụp áo dài Tết đậm chất Sài...
# 4     2024-12-12 12:22:40  Bật mí với cậu một nơi có thể trải nghiệm trướ...
# ...                   ...                                                ...
# 23094 2023-12-06 12:20:20  🧀🧀🧀 #hotteok #pulmuone #hotteokxucxich #hotteo...
# 23095 2023-12-02 11:46:03               bí mật nho nhỏ🫢 #detox #cleanhealthy
# 23096 2023-11-25 11:38:37              chả cá lã vọng 😽 #dememoria #bodymist
# 23097 2023-11-22 11:24:12                            em là đoá hoa đẹp nhất💕
# 23098 2025-03-05 12:24:27  Thích nhất cảm giác đi cafe chill chill giả vờ...
#
#        digged  diversificationId  duetDisplay duetEnabled  forFriend  \
# 0       False            10085.0            0        True      False
# 1       False            10014.0            0        True      False
# 2       False            10085.0            0        True      False
# 3       False            10085.0            0        True      False
# 4       False            10014.0            0         NaN      False
# ...       ...                ...          ...         ...        ...
# 23094   False                NaN            0        True      False
# 23095   False            10014.0            0        True      False
# 23096   False            10041.0            0        True      False
# 23097   False            10040.0            0        True      False
# 23098   False            10085.0            0        True      False
#
#                         id   isAd  itemCommentStatus  item_control.can_repost  \
# 0      7470905424930262289  False                  0                     True
# 1      7464937169858170129  False                  0                     True
# 2      7461630006834367745  False                  0                     True
# 3      7460126319058193685  False                  0                     True
# 4      7447499627772857617  False                  0                     True
# ...                    ...    ...                ...                      ...
# 23094  7309455444219563265  False                  0                     True
# 23095  7307962261954514178   True                  0                     True
# 23096  7305362746793594113   True                  0                     True
# 23097  7304245772847942913  False                  0                     True
# 23098  7478300261098949906  False                  0                     True
#
#       music.authorName  music.duration             music.id  \
# 0       1 phút Sài Gòn            28.0  7470905515782966033
# 1       1 phút Sài Gòn            25.0  7464937228537170689
# 2       1 phút Sài Gòn            28.0  7461630131497683729
# 3       1 phút Sài Gòn            31.0  7460126414354336529
# 4      Trường Linh Bùi            30.0  7445288188953840385
# ...                ...             ...                  ...
# 23094            CUKAK            47.0  7241906069797473029
# 23095       Orinn Sped            60.0  7189852824614914050
# 23096       U Mờ I E 🦋            53.0  7195777000991148826
# 23097         Kiều Chi            56.0  7288889547764288257
# 23098          仁辰 & 于行           170.0  7123789566997252127
#
#        music.isCopyrighted  music.original  \
# 0                     True           False
# 1                     True           False
# 2                    False           False
# 3                    False           False
# 4                     True           False
# ...                    ...             ...
# 23094                 True           False
# 23095                False           False
# 23096                 True           False
# 23097                 True           False
# 23098                False           False
#
#                                  music.title  officalItem  originalItem  \
# 0                  nhạc nền - 1 phút Sài Gòn        False         False
# 1                  nhạc nền - 1 phút Sài Gòn        False         False
# 2                  nhạc nền - 1 phút Sài Gòn        False         False
# 3                  nhạc nền - 1 phút Sài Gòn        False         False
# 4                  Giờ Thì sẽ ra mắt ngày 12        False         False
# ...                                      ...          ...           ...
# 23094           Chạy Khỏi Thế Giới Này Remix        False         False
# 23095  Khi nào mới chịu nói yêu em - sped up        False         False
# 23096      Không Yêu Xin Đừng Nói Piano Ver.        False         False
# 23097           nhạc nền - Phan Thị Kiều Chi        False         False
# 23098                                   蜜桃物语        False         False
#
#        privateItem  secret  shareEnabled  statsV2.collectCount  \
# 0            False   False          True                 12283
# 1            False   False          True                    82
# 2            False   False          True                   251
# 3            False   False          True                   314
# 4            False   False          True                    76
# ...            ...     ...           ...                   ...
# 23094        False   False          True                  2821
# 23095        False   False          True                  8037
# 23096        False   False          True                  4177
# 23097        False   False          True                 10487
# 23098        False   False          True                    10
#
#        statsV2.commentCount  statsV2.diggCount  statsV2.playCount  \
# 0                       414              32100             735300
# 1                       354                694              26100
# 2                        25               4477              41300
# 3                        51               7808              54900
# 4                         3               2731              19700
# ...                     ...                ...                ...
# 23094                   475              62700            1800000
# 23095                   926             119100            2200000
# 23096                   718             182500            3800000
# 23097                   929             220900            4200000
# 23098                    19                705               7206
#
#        statsV2.repostCount  statsV2.shareCount  stitchDisplay stitchEnabled  \
# 0                        0               10200              0          True
# 1                        0                  68              0          True
# 2                        0                 157              0          True
# 3                        0                 315              0          True
# 4                        0                  21              0           NaN
# ...                    ...                 ...            ...           ...
# 23094                    0                 786              0          True
# 23095                    0                 907              0          True
# 23096                    0                 560              0          True
# 23097                    0                 908              0          True
# 23098                    0                  10              0          True
#
#       textLanguage  textTranslatable  video.VQScore  video.bitrate  \
# 0               vi              True          72.87      2660641.0
# 1               vi              True          73.22      3619524.0
# 2               vi              True          72.58      3178076.0
# 3               vi              True          70.57      3162054.0
# 4               vi              True          74.35      1327272.0
# ...            ...               ...            ...            ...
# 23094           un             False          73.59      1464212.0
# 23095           vi              True          71.58      1418490.0
# 23096           vi              True          70.35      1807578.0
# 23097           vi              True          67.83      1308368.0
# 23098           vi              True           0.00      1204880.0
#
#       video.claInfo.enableAutoCaption video.claInfo.hasOriginalAudio  \
# 0                                True                           True
# 1                                True                           True
# 2                                True                           True
# 3                                True                           True
# 4                                True                          False
# ...                               ...                            ...
# 23094                            True                           True
# 23095                            True                           True
# 23096                            True                           True
# 23097                            True                           True
# 23098                            True                           True
#
#       video.codecType video.definition  video.duration video.encodedType  \
# 0                h264             540p              28            normal
# 1                h264             540p              25            normal
# 2                h264             540p              28            normal
# 3                h264             540p              31            normal
# 4                h264             540p              32            normal
# ...               ...              ...             ...               ...
# 23094            h264             540p              82            normal
# 23095            h264             540p             105            normal
# 23096            h264             540p              87            normal
# 23097            h264             540p              94            normal
# 23098            h264             540p             115            normal
#
#       video.format  video.height             video.id video.ratio  \
# 0              mp4          1024  7470905424930262289        540p
# 1              mp4          1024  7464937169858170129        540p
# 2              mp4          1024  7461630006834367745        540p
# 3              mp4          1024  7460126319058193685        540p
# 4              mp4          1024  7447499627772857617        540p
# ...            ...           ...                  ...         ...
# 23094          mp4          1024  7309455444219563265        540p
# 23095          mp4          1024  7307962261954514178        540p
# 23096          mp4          1024  7305362746793594113        540p
# 23097          mp4          1024  7304245772847942913        540p
# 23098          mp4          1024  7478300261098949906        540p
#
#                           video.videoID video.videoQuality  \
# 0      v1c044g50000cumvomnog65hhpslq940             normal
# 1      v1c044g50000cucch7nog65hlk5usma0             normal
# 2      v14044g50000cu6ghuvog65s16m66m0g             normal
# 3      v14044g50000cu3r1onog65n6lp9lcrg             normal
# 4      v1c044g50000ctdda07og65uc3brlesg             normal
# ...                                 ...                ...
# 23094  v10025g50000clo6cavog65lmdshttog             normal
# 23095  v14025g50000cllhgunog65j1cs5j9f0             normal
# 23096  v14025g50000clgtndfog65vbe2jtupg             normal
# 23097  v10025g50000cleu8h7og65j2vs1fq7g             normal
# 23098  v14044g50000cv443f7og65kat3t9uqg             normal
#
#        video.volumeInfo.Loudness  video.volumeInfo.Peak  video.width  \
# 0                           -7.2                1.00000          576
# 1                           -8.3                1.00000          576
# 2                           -7.0                1.00000          576
# 3                          -10.4                1.00000          576
# 4                          -14.8                0.51286          576
# ...                          ...                    ...          ...
# 23094                      -17.3                1.00000          576
# 23095                      -17.9                1.00000          576
# 23096                      -17.9                0.77625          576
# 23097                      -13.8                1.00000          576
# 23098                      -13.5                1.00000          576
#
#        collectTime  video.claInfo.captionsType  \
# 0       1741176061                         NaN
# 1       1741176061                         NaN
# 2       1741176062                         NaN
# 3       1741176062                         NaN
# 4       1741176063                         NaN
# ...            ...                         ...
# 23094   1741177528                         1.0
# 23095   1741177528                         1.0
# 23096   1741177528                         1.0
# 23097   1741177528                         NaN
# 23098   1741177975                         1.0
#
#                                                 hashtags  num_hashtags  \
# 0      [1phutsaigon, saigon, saigondidau, cafesaigon,...             7
# 1      [1phutsaigon, saigon, saigondidau, duxuan, tet...             5
# 2      [1phutsaigon, saigon, saigondidau, halacoffee,...             6
# 3      [1phutsaigon, saigon, saigondidau, saigondamda...             9
# 4      [1phutsaigon, saigondidau, langthangsaigon, tu...             6
# ...                                                  ...           ...
# 23094    [hotteok, pulmuone, hotteokxucxich, hotteokngo]             4
# 23095                              [detox, cleanhealthy]             2
# 23096                              [dememoria, bodymist]             2
# 23097                                                 []             0
# 23098                             [cheesecoffee, diudao]             2
#
#                                      video_transcription  \
# 0      cuối cùng mà mình thấy nhau và rồi tháng mấy đ...
# 1      Nghe xuân sang thấy trong lòng mình chứa chan ...
# 2      bồi hồi liên kết sẽ quay về thăm quê em xuân đ...
# 3      bánh chưng bánh giò bánh chưng tương lai mấy g...
# 4      chờ mãi đến bây giờ thì anh mới nhận ra em mìn...
# ...                                                  ...
# 23094  phô mai gouda và phô mai si da loại hôm nay ca...
# 23095  này này anh thấy em muốn hỏi anh một câu em đừ...
# 23096  thông thường nên được lưu hương rất là lâu đặc...
# 23097  thử thách trái tim bên lề ban công góc nhà ai ...
# 23098  thông minh đến thử bộ sưu tập chị Đào mới toan...
#
#                                                      url
# 0      https://www.tiktok.com/@7128234498731803674/vi...
# 1      https://www.tiktok.com/@7128234498731803674/vi...
# 2      https://www.tiktok.com/@7128234498731803674/vi...
# 3      https://www.tiktok.com/@7128234498731803674/vi...
# 4      https://www.tiktok.com/@7128234498731803674/vi...
# ...                                                  ...
# 23094  https://www.tiktok.com/@6644110999556227073/vi...
# 23095  https://www.tiktok.com/@6644110999556227073/vi...
# 23096  https://www.tiktok.com/@6644110999556227073/vi...
# 23097  https://www.tiktok.com/@6644110999556227073/vi...
# 23098  https://www.tiktok.com/@6644110999556227073/vi...
#
# [23099 rows x 81 columns]

# %% [markdown]
# # Export to Merge

# %% [markdown]
# Lưu DataFrame đã xử lý vào file `merged_data.csv`.

# %%
# merged_df.to_csv("data/processed/merged_data.csv", index=False)

# %%
# merged_df.to_parquet("data/processed/merged_data.parquet", index=False)

# %% [markdown]
# # ========================================

# %%
merged_df.columns
# Out:
# Index(['CategoryType', 'author.commentSetting', 'author.downloadSetting',
#        'author.duetSetting', 'author.ftc', 'author.id', 'author.isADVirtual',
#        'author.isEmbedBanned', 'author.nickname', 'author.openFavorite',
#        'author.privateAccount', 'author.relation', 'author.secUid',
#        'author.secret', 'author.signature', 'author.stitchSetting',
#        'author.uniqueId', 'author.verified', 'authorStats.diggCount',
#        'authorStats.followerCount', 'authorStats.followingCount',
#        'authorStats.friendCount', 'authorStats.heart',
#        'authorStats.heartCount', 'authorStats.videoCount', 'collected',
#        'createTime', 'desc', 'digged', 'diversificationId', 'duetDisplay',
#        'duetEnabled', 'forFriend', 'id', 'isAd', 'itemCommentStatus',
#        'item_control.can_repost', 'music.authorName', 'music.duration',
#        'music.id', 'music.isCopyrighted', 'music.original', 'music.title',
#        'officalItem', 'originalItem', 'privateItem', 'secret', 'shareEnabled',
#        'statsV2.collectCount', 'statsV2.commentCount', 'statsV2.diggCount',
#        'statsV2.playCount', 'statsV2.repostCount', 'statsV2.shareCount',
#        'stitchDisplay', 'stitchEnabled', 'textLanguage', 'textTranslatable',
#        'video.VQScore', 'video.bitrate', 'video.claInfo.enableAutoCaption',
#        'video.claInfo.hasOriginalAudio', 'video.codecType', 'video.definition',
#        'video.duration', 'video.encodedType', 'video.format', 'video.height',
#        'video.id', 'video.ratio', 'video.videoID', 'video.videoQuality',
#        'video.volumeInfo.Loudness', 'video.volumeInfo.Peak', 'video.width',
#        'collectTime', 'video.claInfo.captionsType', 'hashtags', 'num_hashtags',
#        'video_transcription', 'url'],
#       dtype='object')

# %%
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Visual for

# %%
# Define video duration categories
bins = [0, 10, 30, 60, 90, 120, 180, 300, 600, float("inf")]
labels = ["<10s", "10-30s", "30-60s", "60-90s", "90-120s", "2 mins", "3-5 mins", "5-10 mins", ">10 mins"]

# Categorize video durations
video_info_df["video_duration_category"] = pd.cut(video_info_df["video.duration"], bins=bins, labels=labels, right=False)

# Count number of videos in each category
duration_counts = video_info_df["video_duration_category"].value_counts().reindex(labels)

# Calculate total views per video duration category
views_per_category = video_info_df.groupby("video_duration_category")["statsV2.playCount"].sum().reindex(labels)

# Create the figure
fig = go.Figure()

# Add bar chart for number of videos
fig.add_trace(go.Bar(
    x=duration_counts.index,
    y=duration_counts.values,
    name="Number of Videos",
    marker_color="blue",
    yaxis="y1"
))

# Add line chart for total views
fig.add_trace(go.Scatter(
    x=views_per_category.index,
    y=views_per_category,
    name="Total Views",
    mode="lines+markers",
    marker=dict(color="red", size=8),
    line=dict(width=2),
    yaxis="y2"
))

# Update layout
fig.update_layout(
    title="Video Duration vs. Total Views",
    xaxis_title="Video Duration Category",
    
    # Left Y-Axis (Number of Videos)
    yaxis=dict(
        title="Number of Videos",
        side="left",
        showgrid=False
    ),
    
    # Right Y-Axis (Total Views)
    yaxis2=dict(
        title="Total Views",
        side="right",
        overlaying="y",
        showgrid=False
    ),
    
    margin=dict(l=60, r=60, t=50, b=50),
    legend=dict(x=0.1, y=1.1),
)

# Show the figure
fig.show()
# Out:
# C:\Users\029at\AppData\Local\Temp\ipykernel_17884\1644838173.py:12: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
import pandas as pd
import plotly.express as px

# Define video duration categories
bins = [0, 10, 30, 60, 90, 120, 180, 300, 600, float("inf")]
labels = ["<10s", "10-30s", "30-60s", "60-90s", "90-120s", "2 mins", "3-5 mins", "5-10 mins", ">10 mins"]

# Categorize video durations
video_info_df["video_duration_category"] = pd.cut(video_info_df["video.duration"], bins=bins, labels=labels, right=False)

# Melt dataframe to include views, likes, comments, and shares
engagement_df = video_info_df.melt(
    id_vars=["video_duration_category"],
    value_vars=["statsV2.playCount", "statsV2.diggCount", "statsV2.commentCount", "statsV2.shareCount"],
    var_name="Engagement Type",
    value_name="Count"
)

# Rename engagement types for better readability
engagement_df["Engagement Type"] = engagement_df["Engagement Type"].replace({
    "statsV2.playCount": "Views",
    "statsV2.diggCount": "Likes",
    "statsV2.commentCount": "Comments",
    "statsV2.shareCount": "Shares"
})

# Create scatter plot
fig_scatter = px.scatter(
    engagement_df,
    x="video_duration_category",
    y="Count",
    color="Engagement Type",
    title="Video Duration vs. Engagement (Views, Likes, Comments, Shares)",
    labels={"video_duration_category": "Video Duration Category", "Count": "Engagement Count"},
    category_orders={"video_duration_category": labels}
)

# Show figure
fig_scatter.show()
